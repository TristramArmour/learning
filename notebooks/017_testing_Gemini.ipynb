# %%
import google.generativeai as genai
from configparser import ConfigParser

c = ConfigParser()
c.read(r"C:/workspace/APIKEY_personal.ini")
# Out:
# ['C:/workspace/APIKEY_personal.ini']

# %%
genai.configure(api_key=c["KEY"]["GEMINI"])
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# Artificial intelligence (AI) is a broad field encompassing various techniques that enable computers to mimic human intelligence.  There's no single "how it works" answer, as different AI approaches use different methods. However, several core concepts underpin most AI systems:
#
# **1. Data is the Fuel:**  AI systems learn from data. The more relevant and high-quality data they are trained on, the better they perform. This data can be anything from images and text to sensor readings and financial transactions.
#
# **2. Algorithms are the Engine:**  Algorithms are sets of instructions that tell the computer how to process and learn from the data. Different algorithms are suited to different tasks. Some common types include:
#
# * **Machine Learning (ML):**  This is a subset of AI where systems learn from data without explicit programming.  Instead of being explicitly told what to do, they identify patterns and relationships in the data to make predictions or decisions.  ML can be further broken down into:
#     * **Supervised Learning:** The algorithm is trained on labeled data (data where the correct answer is already known).  For example, showing an image classifier many pictures of cats and dogs labeled as such.
#     * **Unsupervised Learning:** The algorithm is trained on unlabeled data and tries to find patterns and structures on its own.  For example, clustering similar customers based on their purchase history.
#     * **Reinforcement Learning:** The algorithm learns through trial and error, receiving rewards or penalties for its actions.  This is often used in robotics and game playing.
#
# * **Deep Learning (DL):** A subset of machine learning that uses artificial neural networks with multiple layers (hence "deep").  These networks are inspired by the structure and function of the human brain.  Deep learning excels at tasks involving complex patterns, such as image recognition, natural language processing, and speech recognition.
#
# * **Expert Systems:** These systems use a knowledge base of rules and facts to make decisions. They are programmed with human expertise in a specific domain.  While powerful in their domain, they are less adaptable than ML or DL systems.
#
# **3. Models are the Representation:**  As AI systems learn, they create models – mathematical representations of the patterns and relationships they've discovered in the data.  These models are used to make predictions or decisions on new, unseen data.
#
# **4. Evaluation and Refinement:**  The performance of AI systems is constantly evaluated.  This involves measuring how accurately they make predictions or perform tasks and identifying areas for improvement.  The models are often refined through techniques like retraining with more data or adjusting the algorithms.
#
#
# **In simpler terms:** Imagine teaching a child to identify a cat.  You'd show them many pictures of cats, pointing out their features (whiskers, pointy ears, etc.).  This is similar to supervised learning.  The child then creates a mental model of what a cat looks like and can identify cats in new pictures.  This mental model is similar to the model an AI system creates.
#
#
# It's important to note that AI is a rapidly evolving field, and new techniques and approaches are constantly being developed.  The above explanation provides a general overview, but the specifics can be quite complex depending on the specific AI system.

# %% [markdown]
# It works!
